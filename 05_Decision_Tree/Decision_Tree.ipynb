# %% [markdown]
# # Дерево решений

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"penguins_size.csv")
df.head()

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [raw]
# island - НАЗВАНИЕ ОСТРОВА НА АРХИПЕЛАГЕ
# culmen_length_mm	culmen_depth_mm	 - ДЛИНА И ВЫСОТА В ММ
# flipper_length_mm	 - КРЫЛО
# body_mass_g - МАССА
# sex - ПОЛ

# %%
df.isna().sum().sum()
# Out:
# np.int64(18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# удаляем то, где есть хотя бы 1 пропуск

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df[df['sex'] == '.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df[df['species']=='Gentoo'].groupby('sex').agg({'body_mass_g': 'mean', 'culmen_length_mm':'mean', 'culmen_depth_mm':'mean',
                                                'flipper_length_mm': 'mean'})
# Out:
#         body_mass_g  culmen_length_mm  culmen_depth_mm  flipper_length_mm
# sex
# .       4875.000000         44.500000        15.700000         217.000000
# FEMALE  4679.741379         45.563793        14.237931         212.706897
# MALE    5484.836066         49.473770        15.718033         221.540984

# %%
df[df['species']=='Gentoo'].groupby('sex').describe().T
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df.at[336, 'sex'] = 'FEMALE'

# %%
sns.pairplot(df, hue='species')

# %% [raw]
# labelEncoding, чтобы перекодировать данные

# %%
X = pd.get_dummies(df.drop('species', axis=1), drop_first=True)

# %%
y = df['species']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_preds = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, base_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        41
#    Chinstrap       0.96      0.96      0.96        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.98      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
ConfusionMatrixDisplay.from_predictions(y_test, base_preds)

# %% [markdown]
# # Можно использовать аттрибуты, которые повляются в деревьях решений

# %%
model.feature_importances_
# Out:
# array([0.33754639, 0.04203954, 0.53120101, 0.01085298, 0.0681854 ,
#        0.01017467, 0.        ])

# %%
pd.DataFrame(data=model.feature_importances_, index= X.columns, columns=['Важность_признаков']).sort_values('Важность_признаков')
# Out:
#                    Важность_признаков
# sex_MALE                     0.000000
# island_Torgersen             0.010175
# body_mass_g                  0.010853
# culmen_depth_mm              0.042040
# island_Dream                 0.068185
# culmen_length_mm             0.337546
# flipper_length_mm            0.531201

# %%
from sklearn.tree import plot_tree

# %%
fig, ax = plt.subplots(figsize=(12,8))

plot_tree(model, ax=ax, feature_names=X.columns, filled=True);

# %% [raw]
# за что отвечает цвет?
# 3 разных цвета
# в зависимости от того, значения какого из трех классов в этом узле имеют наибольшее колво точек
#
# цвета более темные или более светлые, более темные - большая однородность

# %% [markdown]
# функция для понимания как влиют параметры разные на модель

# %%
def report(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test, model_preds))
    print()
    fig, ax = plt.subplots(figsize=(12,8))
    plot_tree(model, ax=ax, feature_names=X.columns, filled=True);

# %%
pr = DecisionTreeClassifier(max_depth=4) #глубина
pr.fit(X_train, y_train)
report(pr)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [raw]
# criterion — функция оценки качества разбиения:
# – для классификации: gini (по умолчанию), entropy;
# – для регрессии: squared_error, friedman_mse, absolute_error.
#
# min_samples_split — минимальное число примеров в узле, чтобы его можно было разбить.
# min_samples_leaf — минимальное число примеров в листе.
# max_depth — максимальная глубина дерева. Чем меньше, тем проще модель.
# max_leaf_nodes — максимальное количество листьев.
# in_impurity_decrease — порог уменьшения примеси, ниже которого разбиение не делается.
# ccp_alpha — параметр пост-обрезки (cost-complexity pruning): чем больше, тем сильнее обрезаем дерево.
# class_weight — веса классов (например, 'balanced') для борьбы с дисбалансом.
